# %%
# !pip install diffusers transformers

# %%
from diffusers import DiffusionPipeline
from huggingface_hub import login
import os
login(token="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")
os.environ["HF_TOKEN"] = "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"
generator = DiffusionPipeline.from_pretrained("nitrosocke/Future-Diffusion")

# %%
generator.to("cuda")

# %%
image = generator("chotta bheem").images[0]

# %%
image.save("generated_image.png")

# %%
image
