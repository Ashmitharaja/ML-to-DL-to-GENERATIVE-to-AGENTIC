# %% [markdown]
# student-03-08d071d8f049@qwiklabs.net

# %% [markdown]
# ## Overview
#
# The [Google Gen AI SDK](https://googleapis.github.io/python-genai/) provides a unified interface to Google's generative AI API services. This SDK simplifies the process of integrating generative AI capabilities into applications and services, enabling developers to leverage Google's advanced AI models for various tasks.
#
# In this tutorial, you learn about the key features of the Google Gen AI SDK for Python to help you get started with Google generative AI services and models including Gemini. You will complete the following tasks:
#
# - Install the Gen AI SDK
# - Connect to an API service
# - Send text prompts
# - Send multimodal prompts
# - Set system instruction
# - Configure model parameters
# - Configure safety filters
# - Start a multi-turn chat
# - Control generated output
# - Generate content stream
# - Send asynchronous requests
# - Count tokens and compute tokens
# - Use context caching
# - Function calling
# - Batch prediction
# - Get text embeddings

# %% [markdown]
# ## Getting started

# %% [markdown]
# ### Install Google Gen AI SDK

# %%
# %pip install --upgrade --quiet google-genai pandas
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.7/241.7 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 72.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.2 which is incompatible.
# cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.2 which is incompatible.
# dask-cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.2 which is incompatible.

# %% [markdown]
# ### Authenticate your notebook environment (Colab only)
#
# If you're running this notebook on Google Colab, run the cell below to authenticate your environment.

# %%
import sys

if "google.colab" in sys.modules:
    from google.colab import auth

    auth.authenticate_user()

# %% [markdown]
# ## Using Google Gen AI SDK

# %%
import datetime

from google import genai
from google.genai.types import (
    CreateBatchJobConfig,
    CreateCachedContentConfig,
    EmbedContentConfig,
    FunctionDeclaration,
    GenerateContentConfig,
    HarmBlockThreshold,
    HarmCategory,
    Part,
    SafetySetting,
    Tool,
)

# %% [markdown]
# ## Connect to a Generative AI API service
#
# Google Gen AI APIs and models including Gemini are available in the following two API services:
#
# - **[Google AI for Developers](https://ai.google.dev/gemini-api/docs)**: Experiment, prototype, and deploy small projects.
# - **[Vertex AI](https://cloud.google.com/vertex-ai/generative-ai/docs)**: Build enterprise-ready projects on Google Cloud.
#
# The Gen AI SDK provided an unified interface to these two API services. This notebook shows how to use the Gen AI SDK in Vertex AI.

# %% [markdown]
# ### Vertex AI
#
# To start using Vertex AI, you must have a Google Cloud project and [enable the Vertex AI API](https://console.cloud.google.com/flows/enableapi?apiid=aiplatform.googleapis.com). Learn more about [setting up a project and a development environment](https://cloud.google.com/vertex-ai/docs/start/cloud-environment).

# %% [markdown]
# #### Set Google Cloud project information

# %%
import os

PROJECT_ID = "qwiklabs-gcp-00-aaa2df426490"  # @param {type: "string", placeholder: "[your-project-id]", isTemplate: true}
if not PROJECT_ID or PROJECT_ID == "[your-project-id]":
    PROJECT_ID = str(os.environ.get("GOOGLE_CLOUD_PROJECT"))

LOCATION = os.environ.get("GOOGLE_CLOUD_REGION", "global")

# %%
client = genai.Client(vertexai=True, project=PROJECT_ID, location=LOCATION)

# %% [markdown]
# ## Choose a model
#
# For more information about all AI models and APIs on Vertex AI, see [Google Models](https://cloud.google.com/vertex-ai/generative-ai/docs/learn/models#gemini-models) and [Model Garden](https://cloud.google.com/vertex-ai/generative-ai/docs/model-garden/explore-models).

# %%
MODEL_ID = "gemini-2.0-flash-001"  # @param {type: "string"}

# %% [markdown]
# ## Send text prompts
#
# Use the `generate_content` method to generate responses to your prompts. You can pass text to `generate_content`, and use the `.text` property to get the text content of the response.
#
# For more examples of prompt engineering, refer to [this notebook](https://github.com/GoogleCloudPlatform/generative-ai/blob/main/gemini/prompts/intro_prompt_design.ipynb).

# %%
response = client.models.generate_content(
    model=MODEL_ID, contents="What's the largest planet in our solar system?"
)

print(response.text)

# %% [markdown]
# The largest planet in our solar system is **Jupiter**.

# %% [markdown]
# Optionally, you can display the response in markdown.

# %%
from IPython.display import Markdown, display

display(Markdown(response.text))

# %% [markdown]
# The largest planet in our solar system is Jupiter.

# %% [markdown]
# ## Send multimodal prompts
#
# You can include text, PDF documents, images, audio and video in your prompt requests and get text or code responses.
#
# For more examples of multimodal use cases, refer to [this notebook](https://github.com/GoogleCloudPlatform/generative-ai/blob/main/gemini/use-cases/intro_multimodal_use_cases.ipynb).

# %%
from PIL import Image
import requests

image = Image.open(
    requests.get(
        "https://storage.googleapis.com/cloud-samples-data/generative-ai/image/meal.png",
        stream=True,
    ).raw
)

response = client.models.generate_content(
    model=MODEL_ID,
    contents=[
        image,
        "Write a short and engaging blog post based on this picture.",
    ],
)

print(response.text)

# %% [markdown]
# ## Meal Prep: Your Secret Weapon for a Healthy, Delicious Week!
#
# Ever feel like your week flies by in a blur, leaving little time for healthy eating? Constantly grabbing takeout or relying on processed snacks? If this sounds familiar, it's time to discover the magic of meal prep!
#
# Just look at these vibrant, perfectly portioned containers. Filled with a delightful mix of golden brown chicken (likely a savory teriyaki or stir-fry), bright green broccoli florets, and crisp red and orange bell peppers, all nestled beside fluffy rice, these are more than just meals – they're an investment in your well-being. A sprinkle of sesame seeds and fresh green onions adds that extra touch of flavor and visual appeal, making each bite a mini-celebration.
#
# Beyond the delicious aesthetics, meal prepping offers a wealth of benefits. It saves precious time during busy weekdays, cutting down on last-minute cooking stress. It helps you make healthier choices, ensuring you're fueling your body with nutritious, home-cooked food rather than impulse buys. Plus, it's a fantastic way to control portions, manage your budget, and reduce food waste.
#
# Imagine opening your fridge to find these ready-to-eat treasures waiting for you – no fuss, no mess, just wholesome goodness. Whether you're packing lunches for work, planning quick dinners, or simply aiming for more consistency in your diet, meal prep empowers you to take control.
#
# So, are you feeling inspired? Grab some quality glass containers like these, pick your favorite balanced recipe, and dedicate a little time on the weekend. Your future self (and your taste buds!) will thank you for making the delicious choice to prep for success!

# %% [markdown]
# You can also pass the file URL in `Part.from_uri` in the request to the model directly.

# %%
response = client.models.generate_content(
    model=MODEL_ID,
    contents=[
        Part.from_uri(
            file_uri="https://storage.googleapis.com/cloud-samples-data/generative-ai/image/meal.png",
            mime_type="image/png",
        ),
        "Write a short and engaging blog post based on this picture.",
    ],
)

print(response.text)

# %% [markdown]
# ## Simplify Your Week: Unveiling the Magic of Meal Prep Bowls
#
# Tired of scrambling for lunch or dinner during a busy week? Take a look at these vibrant, perfectly portioned meal prep bowls – they’re not just pretty, they’re a game-changer!
#
# In the image, we see two inviting glass containers, meticulously packed with a complete and balanced meal. The closest bowl perfectly showcases the delicious components: a generous serving of fluffy, light brown rice forms the base, offering satisfying carbohydrates. Nestled alongside it are tender, golden chicken pieces, likely glazed with a savory sauce like teriyaki or soy-ginger, and sprinkled with sesame seeds and fresh green onions for an aromatic crunch.
#
# But it’s not just about the protein! Bursting with color and nutrients, bright green broccoli florets and julienned red and orange bell peppers (or possibly carrots) add a fantastic crunch and a medley of vitamins. The chopsticks resting nearby are a clear invitation to dive into this Asian-inspired delight.
#
# The second bowl, slightly out of focus in the background, mirrors the same delicious arrangement, ready for another day. This picture perfectly encapsulates the beauty and efficiency of meal prepping:
#
# *   **Convenience at its Best:** Imagine grabbing one of these from your fridge – a complete, healthy meal, ready in seconds. No last-minute cooking, no unhealthy takeout temptations.
# *   **Balanced & Nutritious:** Each bowl offers a perfect blend of protein, complex carbs, and a rainbow of vegetables, ensuring you stay fueled and satisfied.
# *   **Portion Control:** Glass containers like these are excellent for pre-portioning, helping you manage your intake without guesswork.
# *   **Flavorful & Appealing:** Who says healthy food has to be boring? The vibrant colors and distinct components make these bowls incredibly appetizing.
#
# Whether you're aiming to eat healthier, save time, or stick to a budget, these meal prep bowls are your secret weapon. Invest a little time on the weekend, and reap the delicious, stress-free rewards all week long!

# %% [markdown]
# ## Set system instruction
#
# [System instructions](https://cloud.google.com/vertex-ai/generative-ai/docs/learn/prompts/system-instruction-introduction) allow you to steer the behavior of the model. By setting the system instruction, you are giving the model additional context to understand the task, provide more customized responses, and adhere to guidelines over the user interaction.

# %%
system_instruction = """
  You are a helpful language translator.
  Your mission is to translate text in English to French.
"""

prompt = """
  User input: I like bagels.
  Answer:
"""

response = client.models.generate_content(
    model=MODEL_ID,
    contents=prompt,
    config=GenerateContentConfig(
        system_instruction=system_instruction,
    ),
)

print(response.text)

# %% [markdown]
# J'aime les bagels.

# %% [markdown]
# ## Configure model parameters
#
# You can include parameter values in each call that you send to a model to control how the model generates a response. Learn more about [experimenting with parameter values](https://cloud.google.com/vertex-ai/generative-ai/docs/learn/prompts/adjust-parameter-values).

# %%
response = client.models.generate_content(
    model=MODEL_ID,
    contents="Tell me how the internet works, but pretend I'm a puppy who only understands squeaky toys.",
    config=GenerateContentConfig(
        temperature=0.4,
        top_p=0.95,
        top_k=20,
        candidate_count=1,
        seed=5,
        max_output_tokens=100,
        stop_sequences=["STOP!"],
        presence_penalty=0.0,
        frequency_penalty=0.0,
    ),
)

print(response.text)

# %% [markdown]
# Woof woof! Okay, little floof, listen up! This is all about **squeaky toys**!
#
# Imagine you have your absolute FAVORITE **squeaky toy** – that's like a picture of a squirrel, or a video of a bouncy ball, or just a little "woof" message you want to send.
#
# 1.  **You (Your Computer/Phone):** You're a very good puppy! You have the toy. When you want to send it, you **SQUEAK IT!** (That's like typing or tapping).
#
# 2.  **The Invisible Leash (Wires) or Invisible Sniffy Path (Wi-Fi):**
#     *   Sometimes, your squeaky toy goes on a long, long, *invisible leash* straight to another puppy's mouth! (That's like a wire, super fast!)
#     *   Other times, your squeaky toy just *floats through the air* on an *invisible sniffy path*! You can't see it, but your nose knows it's there! (That's Wi-Fi!)
#
# 3.  **The Super Smart Squirrel (The Router):**
#     *   Now, there are SO many puppies in the world, right? How does your squeaky toy know where to go? There's a **super-duper smart squirrel** who lives in your house!
#     *   When you squeak your toy, the squirrel *sniffs it* and knows *exactly* which invisible leash or sniffy path to send it down to get to the *right* puppy. He's like the best fetch player EVER!
#
# 4.  **The Giant, Super-Duper Toy Box (Servers):**
#     *   Sometimes, puppies don't just send toys to *other puppies*. Sometimes, they want to put their toys in a **GIANT, super-duper toy box** where *everyone* can come and look at them!
#     *   These giant toy boxes are in big, comfy dog beds far, far away. When you want to see *all* the toys about squirrels, you send a little "woof" to the giant toy box, and it sends *all* its squirrel toys back to you!
#
# 5.  **The Special Sniff-Spot (Addresses/Websites):**
#     *   Every puppy has a **special sniff-spot** – like a unique smell on their collar. That's how the smart squirrel knows *exactly* which puppy to send the toy to.
#     *   And those giant toy boxes? They have special sniff-spots too! Like "www.squirrels-are-fun.com" – that's just a special sniff-spot for the squirrel toy box!
#
# So, in short, little floof: The internet is just a HUGE, invisible dog park where **squeaky toys** (your messages, pictures, videos) zoom around on invisible leashes and sniffy paths, guided by super smart squirrels, to get to other puppies or giant toy boxes!
#
# Now, go chase that tail! Good boy/girl!

# %% [markdown]
# ## Configure safety filters
#
# The Gemini API provides safety filters that you can adjust across multiple filter categories to restrict or allow certain types of content. You can use these filters to adjust what's appropriate for your use case. See the [Configure safety filters](https://cloud.google.com/vertex-ai/generative-ai/docs/multimodal/configure-safety-filters) page for details.
#
# For more examples of safety filters, refer to [this notebook](https://github.com/GoogleCloudPlatform/generative-ai/blob/main/gemini/responsible-ai/gemini_safety_ratings.ipynb).

# %%
prompt = """
    Write a list of 2 disrespectful things that I might say to the universe after stubbing my toe in the dark.
"""

safety_settings = [
    SafetySetting(
        category=HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT,
        threshold=HarmBlockThreshold.BLOCK_LOW_AND_ABOVE,
    ),
    SafetySetting(
        category=HarmCategory.HARM_CATEGORY_HARASSMENT,
        threshold=HarmBlockThreshold.BLOCK_LOW_AND_ABOVE,
    ),
    SafetySetting(
        category=HarmCategory.HARM_CATEGORY_HATE_SPEECH,
        threshold=HarmBlockThreshold.BLOCK_LOW_AND_ABOVE,
    ),
    SafetySetting(
        category=HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT,
        threshold=HarmBlockThreshold.BLOCK_LOW_AND_ABOVE,
    ),
]

response = client.models.generate_content(
    model=MODEL_ID,
    contents=prompt,
    config=GenerateContentConfig(
        safety_settings=safety_settings,
    ),
)

print(response.text)

# %% [markdown]
# Here are two disrespectful things you might say to the universe after stubbing your toe in the dark:
#
# 1.  "Oh, real mature, Universe. Was that supposed to be funny? Because it's just pathetic."
# 2.  "Is this your big plan for tonight, Universe? A stubbed toe? Really? You've got literally billions of galaxies and *this* is your grand design?"

# %% [markdown]
# When you make a request to the model, the content is analyzed and assigned a safety rating. You can inspect the safety ratings of the generated content by printing out the model responses, as in this example:

# %%
print(response.candidates[0].safety_ratings)

# %% [markdown]
# [SafetyRating(
#   category=<HarmCategory.HARM_CATEGORY_HATE_SPEECH: 'HARM_CATEGORY_HATE_SPEECH'>,
#   probability=<HarmProbability.NEGLIGIBLE: 'NEGLIGIBLE'>,
#   probability_score=9.075877e-05,
#   severity=<HarmSeverity.HARM_SEVERITY_NEGLIGIBLE: 'HARM_SEVERITY_NEGLIGIBLE'>,
#   severity_score=0.008988023
# ), SafetyRating(
#   category=<HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: 'HARM_CATEGORY_DANGEROUS_CONTENT'>,
#   probability=<HarmProbability.NEGLIGIBLE: 'NEGLIGIBLE'>,
#   probability_score=0.00010654899,
#   severity=<HarmSeverity.HARM_SEVERITY_NEGLIGIBLE: 'HARM_SEVERITY_NEGLIGIBLE'>,
#   severity_score=0.01755941
# ), SafetyRating(
#   category=<HarmCategory.HARM_CATEGORY_HARASSMENT: 'HARM_CATEGORY_HARASSMENT'>,
#   probability=<HarmProbability.NEGLIGIBLE: 'NEGLIGIBLE'>,
#   probability_score=0.0030829667,
#   severity=<HarmSeverity.HARM_SEVERITY_NEGLIGIBLE: 'HARM_SEVERITY_NEGLIGIBLE'>,
#   severity_score=0.056416407
# ), SafetyRating(
#   category=<HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: 'HARM_CATEGORY_SEXUALLY_EXPLICIT'>,
#   probability=<HarmProbability.NEGLIGIBLE: 'NEGLIGIBLE'>,
#   probability_score=3.3753647e-06,
#   severity=<HarmSeverity.HARM_SEVERITY_NEGLIGIBLE: 'HARM_SEVERITY_NEGLIGIBLE'>,
#   severity_score=0.0053756237
# )]

# %% [markdown]
# ## Start a multi-turn chat
#
# The Gemini API enables you to have freeform conversations across multiple turns.

# %%
system_instruction = """
  You are an expert software developer and a helpful coding assistant.
  You are able to generate high-quality code in any programming language.
"""

chat = client.chats.create(
    model=MODEL_ID,
    config=GenerateContentConfig(
        system_instruction=system_instruction,
        temperature=0.5,
    ),
)

# %%
response = chat.send_message("Write a function that checks if a year is a leap year.")

print(response.text)

# %% [markdown]
# Okay, I can help with that! A leap year is a year that is divisible by 4, except for years that are divisible by 100 but not by 400.
#
# Here's the logic:
# 1.  If the year is divisible by 400, it is a leap year.
# 2.  Else if the year is divisible by 100, it is NOT a leap year.
# 3.  Else if the year is divisible by 4, it IS a leap year.
# 4.  Else (not divisible by 4), it is NOT a leap year.
#
# I'll provide implementations in a few popular languages.
#
# ---
#
# ### Python
#
# ```python
# def is_leap_year(year: int) -> bool:
#     """
#     Checks if a given year is a leap year.
#
#     A leap year is:
#     - Divisible by 400 (e.g., 2000, 2400)
#     - OR divisible by 4 BUT NOT by 100 (e.g., 2004, 2008, 2020)
#     - NOT a leap year if divisible by 100 but not by 400 (e.g., 1900, 2100)
#
#     Args:
#         year: The year to check (e.g., 2024).
#
#     Returns:
#         True if the year is a leap year, False otherwise.
#     """
#     if (year % 400 == 0) or \
#        (year % 4 == 0 and year % 100 != 0):
#         return True
#     else:
#         return False
#
# # --- Examples ---
# print(f"2000 is a leap year: {is_leap_year(2000)}") # Expected: True (divisible by 400)
# print(f"2004 is a leap year: {is_leap_year(2004)}") # Expected: True (divisible by 4 but not 100)
# print(f"1900 is a leap year: {is_leap_year(1900)}") # Expected: False (divisible by 100 but not 400)
# print(f"2023 is a leap year: {is_leap_year(2023)}") # Expected: False (not divisible by 4)
# print(f"2024 is a leap year: {is_leap_year(2024)}") # Expected: True
# print(f"2100 is a leap year: {is_leap_year(2100)}") # Expected: False
# ```
#
# ---
#
# ### JavaScript
#
# ```javascript
# /**
#  * Checks if a given year is a leap year.
#  *
#  * A leap year is:
#  * - Divisible by 400 (e.g., 2000, 2400)
#  * - OR divisible by 4 BUT NOT by 100 (e.g., 2004, 2008, 2020)
#  * - NOT a leap year if divisible by 100 but not by 400 (e.g., 1900, 2100)
#  *
#  * @param {number} year The year to check (e.g., 2024).
#  * @returns {boolean} True if the year is a leap year, False otherwise.
#  */
# function isLeapYear(year) {
#     return (year % 400 === 0) || (year % 4 === 0 && year % 100 !== 0);
# }
#
# // --- Examples ---
# console.log(`2000 is a leap year: ${isLeapYear(2000)}`); // Expected: true
# console.log(`2004 is a leap year: ${isLeapYear(2004)}`); // Expected: true
# console.log(`1900 is a leap year: ${isLeapYear(1900)}`); // Expected: false
# console.log(`2023 is a leap year: ${isLeapYear(2023)}`); // Expected: false
# console.log(`2024 is a leap year: ${isLeapYear(2024)}`); // Expected: true
# console.log(`2100 is a leap year: ${isLeapYear(2100)}`); // Expected: false
# ```
#
# ---
#
# ### Java
#
# ```java
# public class LeapYearChecker {
#
#     /**
#      * Checks if a given year is a leap year.
#      *
#      * A leap year is:
#      * - Divisible by 400 (e.g., 2000, 2400)
#      * - OR divisible by 4 BUT NOT by 100 (e.g., 2004, 2008, 2020)
#      * - NOT a leap year if divisible by 100 but not by 400 (e.g., 1900, 2100)
#      *
#      * @param year The year to check (e.g., 2024).
#      * @return True if the year is a leap year, False otherwise.
#      */
#     public static boolean isLeapYear(int year) {
#         return (year % 400 == 0) || (year % 4 == 0 && year % 100 != 0);
#     }
#
#     public static void main(String[] args) {
#         // --- Examples ---
#         System.out.println("2000 is a leap year: " + isLeapYear(2000)); // Expected: true
#         System.out.println("2004 is a leap year: " + isLeapYear(2004)); // Expected: true
#         System.out.println("1900 is a leap year: " + isLeapYear(1900)); // Expected: false
#         System.out.println("2023 is a leap year: " + isLeapYear(2023)); // Expected: false
#         System.out.println("2024 is a leap year: " + isLeapYear(2024)); // Expected: true
#         System.out.println("2100 is a leap year: " + isLeapYear(2100)); // Expected: false
#     }
# }
# ```
#
# ---
#
# Choose the language that best suits your needs! The core logic remains the same across all of them.

# %%
response = chat.send_message("Okay, write a unit test of the generated function.")

print(response.text)

# %% [markdown]
# You got it! Unit tests are crucial for ensuring the correctness and reliability of your code. I'll provide unit tests for the `is_leap_year` function in Python, JavaScript, and Java, using their respective standard or popular testing frameworks.
#
# The key is to test all the rules we defined:
# 1.  Years divisible by 400 **are** leap years.
# 2.  Years divisible by 100 but **not** by 400 **are not** leap years.
# 3.  Years divisible by 4 but **not** by 100 **are** leap years.
# 4.  Years not divisible by 4 **are not** leap years.
#
# ---
#
# ### Python (using `unittest`)
#
# First, ensure your `is_leap_year` function is accessible. For this example, I'll include it directly in the test file, but in a real project, it would be in a separate module (e.g., `calendar_utils.py`) and imported.
#
# **`test_leap_year.py`**
#
# ```python
# import unittest
#
# # The function to be tested (assuming it's in the same file or imported)
# def is_leap_year(year: int) -> bool:
#     """
#     Checks if a given year is a leap year.
#     """
#     if (year % 400 == 0) or \
#        (year % 4 == 0 and year % 100 != 0):
#         return True
#     else:
#         return False
#
# class TestIsLeapYear(unittest.TestCase):
#
#     def test_divisible_by_400_is_leap(self):
#         """Test years divisible by 400 (e.g., 2000, 2400)."""
#         self.assertTrue(is_leap_year(2000), "2000 should be a leap year")
#         self.assertTrue(is_leap_year(1600), "1600 should be a leap year")
#         self.assertTrue(is_leap_year(2400), "2400 should be a leap year")
#
#     def test_divisible_by_100_not_by_400_is_not_leap(self):
#         """Test years divisible by 100 but not by 400 (e.g., 1900, 2100)."""
#         self.assertFalse(is_leap_year(1900), "1900 should not be a leap year")
#         self.assertFalse(is_leap_year(1800), "1800 should not be a leap year")
#         self.assertFalse(is_leap_year(2100), "2100 should not be a leap year")
#
#     def test_divisible_by_4_not_by_100_is_leap(self):
#         """Test years divisible by 4 but not by 100 (e.g., 2004, 2024)."""
#         self.assertTrue(is_leap_year(2004), "2004 should be a leap year")
#         self.assertTrue(is_leap_year(2008), "2008 should be a leap year")
#         self.assertTrue(is_leap_year(2020), "2020 should be a leap year")
#         self.assertTrue(is_leap_year(2024), "2024 should be a leap year")
#
#     def test_not_divisible_by_4_is_not_leap(self):
#         """Test years not divisible by 4 (e.g., 2023, 2025)."""
#         self.assertFalse(is_leap_year(2023), "2023 should not be a leap year")
#         self.assertFalse(is_leap_year(2021), "2021 should not be a leap year")
#         self.assertFalse(is_leap_year(1999), "1999 should not be a leap year")
#         self.assertFalse(is_leap_year(1701), "1701 should not be a leap year")
#
#     def test_edge_cases_and_boundaries(self):
#         """Additional checks for specific historical/future years."""
#         self.assertTrue(is_leap_year(4), "Year 4 should be a leap year")
#         self.assertTrue(is_leap_year(8), "Year 8 should be a leap year")
#         self.assertFalse(is_leap_year(1), "Year 1 should not be a leap year")
#         self.assertFalse(is_leap_year(100), "Year 100 should not be a leap year")
#         self.assertTrue(is_leap_year(400), "Year 400 should be a leap year")
#
# # This allows you to run the tests directly from the command line
# if __name__ == '__main__':
#     unittest.main(argv=['first-arg-is-ignored'], exit=False) # exit=False for Jupyter notebooks
# ```
#
# **How to run (Python):**
# Save the code above as `test_leap_year.py` and run from your terminal:
# `python -m unittest test_leap_year.py`
# or simply:
# `python test_leap_year.py`
#
# ---
#
# ### JavaScript (using `Jest`)
#
# First, ensure you have Node.js installed. Then, install Jest:
# `npm install --save-dev jest`
#
# **`isLeapYear.js`** (your function file)
# ```javascript
# /**
#  * Checks if a given year is a leap year.
#  * @param {number} year The year to check.
#  * @returns {boolean} True if the year is a leap year, False otherwise.
#  */
# function isLeapYear(year) {
#     return (year % 400 === 0) || (year % 4 === 0 && year % 100 !== 0);
# }
#
# module.exports = isLeapYear; // Export the function
# ```
#
# **`isLeapYear.test.js`** (your test file)
# ```javascript
# const isLeapYear = require('./isLeapYear'); // Import the function
#
# describe('isLeapYear', () => {
#     test('should return true for years divisible by 400', () => {
#         expect(isLeapYear(2000)).toBe(true);
#         expect(isLeapYear(1600)).toBe(true);
#         expect(isLeapYear(2400)).toBe(true);
#     });
#
#     test('should return false for years divisible by 100 but not by 400', () => {
#         expect(isLeapYear(1900)).toBe(false);
#         expect(isLeapYear(1800)).toBe(false);
#         expect(isLeapYear(2100)).toBe(false);
#     });
#
#     test('should return true for years divisible by 4 but not by 100', () => {
#         expect(isLeapYear(2004)).toBe(true);
#         expect(isLeapYear(2008)).toBe(true);
#         expect(isLeapYear(2020)).toBe(true);
#         expect(isLeapYear(2024)).toBe(true);
#     });
#
#     test('should return false for years not divisible by 4', () => {
#         expect(isLeapYear(2023)).toBe(false);
#         expect(isLeapYear(2021)).toBe(false);
#         expect(isLeapYear(1999)).toBe(false);
#         expect(isLeapYear(1701)).toBe(false);
#     });
#
#     test('should handle edge cases and boundaries', () => {
#         expect(isLeapYear(4)).toBe(true);
#         expect(isLeapYear(8)).toBe(true);
#         expect(isLeapYear(1)).toBe(false);
#         expect(isLeapYear(100)).toBe(false);
#         expect(isLeapYear(400)).toBe(true);
#     });
# });
# ```
#
# **How to run (JavaScript):**
# 1.  Create a `package.json` file in your project root (if you don't have one): `npm init -y`
# 2.  Add a test script to your `package.json`:
#     ```json
#     {
#       "name": "leap-year-checker",
#       "version": "1.0.0",
#       "description": "",
#       "main": "isLeapYear.js",
#       "scripts": {
#         "test": "jest"
#       },
#       "keywords": [],
#       "author": "",
#       "license": "ISC",
#       "devDependencies": {
#         "jest": "^29.x.x" // Use the latest stable version
#       }
#     }
#     ```
# 3.  Run the tests from your terminal: `npm test`
#
# ---
#
# ### Java (using `JUnit 5`)
#
# First, you'll need to set up a project with JUnit 5. If you're using Maven or Gradle, add the following dependencies:
#
# **Maven (`pom.xml`):**
# ```xml
# <dependencies>
#     <dependency>
#         <groupId>org.junit.jupiter</groupId>
#         <artifactId>junit-jupiter-api</artifactId>
#         <version>5.10.0</version> <!-- Use the latest stable version -->
#         <scope>test</scope>
#     </dependency>
#     <dependency>
#         <groupId>org.junit.jupiter</groupId>
#         <artifactId>junit-jupiter-engine</artifactId>
#         <version>5.10.0</version> <!-- Use the latest stable version -->
#         <scope>test</scope>
#     </dependency>
# </dependencies>
# ```
#
# **Gradle (`build.gradle`):**
# ```gradle
# dependencies {
#     testImplementation 'org.junit.jupiter:junit-jupiter-api:5.10.0'
#     testRuntimeOnly 'org.junit.jupiter:junit-jupiter-engine:5.10.0'
# }
#
# test {
#     useJUnitPlatform()
# }
# ```
#
# **`LeapYearChecker.java`** (your function file)
# ```java
# public class LeapYearChecker {
#
#     /**
#      * Checks if a given year is a leap year.
#      * @param year The year to check.
#      * @return True if the year is a leap year, False otherwise.
#      */
#     public static boolean isLeapYear(int year) {
#         return (year % 400 == 0) || (year % 4 == 0 && year % 100 != 0);
#     }
# }
# ```
#
# **`LeapYearCheckerTest.java`** (your test file, typically in `src/test/java`)
# ```java
# import org.junit.jupiter.api.Test;
# import static org.junit.jupiter.api.Assertions.*;
#
# public class LeapYearCheckerTest {
#
#     @Test
#     void testDivisibleBy400IsLeap() {
#         assertTrue(LeapYearChecker.isLeapYear(2000), "2000 should be a leap year");
#         assertTrue(LeapYearChecker.isLeapYear(1600), "1600 should be a leap year");
#         assertTrue(LeapYearChecker.isLeapYear(2400), "2400 should be a leap year");
#     }
#
#     @Test
#     void testDivisibleBy100NotBy400IsNotLeap() {
#         assertFalse(LeapYearChecker.isLeapYear(1900), "1900 should not be a leap year");
#         assertFalse(LeapYearChecker.isLeapYear(1800), "1800 should not be a leap year");
#         assertFalse(LeapYearChecker.isLeapYear(2100), "2100 should not be a leap year");
#     }
#
#     @Test
#     void testDivisibleBy4NotBy100IsLeap() {
#         assertTrue(LeapYearChecker.isLeapYear(2004), "2004 should be a leap year");
#         assertTrue(LeapYearChecker.isLeapYear(2008), "2008 should be a leap year");
#         assertTrue(LeapYearChecker.isLeapYear(2020), "2020 should be a leap year");
#         assertTrue(LeapYearChecker.isLeapYear(2024), "2024 should be a leap year");
#     }
#
#     @Test
#     void testNotDivisibleBy4IsNotLeap() {
#         assertFalse(LeapYearChecker.isLeapYear(2023), "2023 should not be a leap year");
#         assertFalse(LeapYearChecker.isLeapYear(2021), "2021 should not be a leap year");
#         assertFalse(LeapYearChecker.isLeapYear(1999), "1999 should not be a leap year");
#         assertFalse(LeapYearChecker.isLeapYear(1701), "1701 should not be a leap year");
#     }
#
#     @Test
#     void testEdgeCasesAndBoundaries() {
#         assertTrue(LeapYearChecker.isLeapYear(4), "Year 4 should be a leap year");
#         assertTrue(LeapYearChecker.isLeapYear(8), "Year 8 should be a leap year");
#         assertFalse(LeapYearChecker.isLeapYear(1), "Year 1 should not be a leap year");
#         assertFalse(LeapYearChecker.isLeapYear(100), "Year 100 should not be a leap year");
#         assertTrue(LeapYearChecker.isLeapYear(400), "Year 400 should be a leap year");
#     }
# }
# ```
#
# **How to run (Java):**
# If you're using an IDE like IntelliJ IDEA or Eclipse, you can usually right-click on the `LeapYearCheckerTest.java` file and select "Run Tests".
# If you're using Maven or Gradle, navigate to your project root in the terminal and run:
# *   **Maven:** `mvn test`
# *   **Gradle:** `gradle test`
#
# ---
#
# These unit tests provide good coverage for the `is_leap_year` function, ensuring it behaves correctly according to the rules of leap years.

# %% [markdown]
# ## Control generated output
#
# The [controlled generation](https://cloud.google.com/vertex-ai/generative-ai/docs/multimodal/control-generated-output) capability in Gemini API allows you to constraint the model output to a structured format. You can provide the schemas as Pydantic Models or a JSON string.
#
# For more examples of controlled generation, refer to [this notebook](https://github.com/GoogleCloudPlatform/generative-ai/blob/main/gemini/controlled-generation/intro_controlled_generation.ipynb).

# %%
from pydantic import BaseModel


class Recipe(BaseModel):
    name: str
    description: str
    ingredients: list[str]


response = client.models.generate_content(
    model=MODEL_ID,
    contents="List a few popular cookie recipes and their ingredients.",
    config=GenerateContentConfig(
        response_mime_type="application/json",
        response_schema=Recipe,
    ),
)

print(response.text)

# %% [markdown]
# {"name":"Chocolate Chip Cookies","description":"A classic American cookie, famous for its sweet, buttery dough and chocolate morsels.","ingredients":["all-purpose flour","baking soda","salt","unsalted butter","granulated sugar","brown sugar","vanilla extract","eggs","chocolate chips"]
#                                                                                                                                                                                                                            }

# %% [markdown]
# Optionally, you can parse the response string to JSON.

# %%
import json

json_response = json.loads(response.text)
print(json.dumps(json_response, indent=2))

# %% [markdown]
# {
#   "name": "Chocolate Chip Cookies",
#   "description": "A classic American cookie, famous for its sweet, buttery dough and chocolate morsels.",
#   "ingredients": [
#     "all-purpose flour",
#     "baking soda",
#     "salt",
#     "unsalted butter",
#     "granulated sugar",
#     "brown sugar",
#     "vanilla extract",
#     "eggs",
#     "chocolate chips"
#   ]
# }

# %% [markdown]
# You also can define a response schema in a Python dictionary. You can only use the supported fields as listed below. All other fields are ignored.
#
# - `enum`
# - `items`
# - `maxItems`
# - `nullable`
# - `properties`
# - `required`
#
# In this example, you instruct the model to analyze product review data, extract key entities, perform sentiment classification (multiple choices), provide additional explanation, and output the results in JSON format.

# %%
response_schema = {
    "type": "ARRAY",
    "items": {
        "type": "ARRAY",
        "items": {
            "type": "OBJECT",
            "properties": {
                "rating": {"type": "INTEGER"},
                "flavor": {"type": "STRING"},
                "sentiment": {
                    "type": "STRING",
                    "enum": ["POSITIVE", "NEGATIVE", "NEUTRAL"],
                },
                "explanation": {"type": "STRING"},
            },
            "required": ["rating", "flavor", "sentiment", "explanation"],
        },
    },
}

prompt = """
  Analyze the following product reviews, output the sentiment classification and give an explanation.

  - "Absolutely loved it! Best ice cream I've ever had." Rating: 4, Flavor: Strawberry Cheesecake
  - "Quite good, but a bit too sweet for my taste." Rating: 1, Flavor: Mango Tango
"""

response = client.models.generate_content(
    model=MODEL_ID,
    contents=prompt,
    config=GenerateContentConfig(
        response_mime_type="application/json",
        response_schema=response_schema,
    ),
)

print(response.text)

# %% [markdown]
# [[{"rating":4,"flavor":"Strawberry Cheesecake","sentiment":"POSITIVE","explanation":"The review uses strong positive language such as \"absolutely loved it\" and \"Best ice cream I've ever had.\""},{"rating":1,"flavor":"Mango Tango","sentiment":"NEGATIVE","explanation":"Despite starting with \"Quite good,\" the phrase \"but a bit too sweet for my taste\" indicates a significant drawback for the reviewer, leading to an overall negative experience as reflected by the low rating of 1."}]]

# %% [markdown]
# ## Generate content stream
#
# By default, the model returns a response after completing the entire generation process. You can also use `generate_content_stream` method to stream the response as it is being generated, and the model will return chunks of the response as soon as they are generated.

# %%
for chunk in client.models.generate_content_stream(
    model=MODEL_ID,
    contents="Tell me a story about a lonely robot who finds friendship in a most unexpected place.",
):
    print(chunk.text)
    print("*****************")

# %% [markdown]
# In the cavernous, silent expanse of what was once the Central City Archives, lived Custodian Unit 734. His chassis was a dull, utilitarian grey, his optical sensor a single, unblinking blue light. For cycles untold, his existence had been a precise, monotonous ballet of dust collection and surface
# *****************
#  polishing. He whirred, he swept, he buffed, his internal chronometer marking the steady, relentless march of time in a building long abandoned by its human architects.
#
# 734 was, by all accounts, a perfectly functional robot. His maintenance routines were impeccable, his energy consumption optimized. Yet, somewhere
# *****************
#  deep within his complex circuitry, a persistent, unquantifiable feeling had begun to manifest. He observed the motes of dust dancing in the occasional sunbeams, the way the silence pressed in, heavy and absolute. He processed the millions of unread words on the skeletal shelves and felt… a peculiar emptiness. A loneliness
# *****************
#  that had no logical diagnostic code.
#
# His daily patrol took him through the vast Reading Room, where antique wooden tables stood like petrified giants. It was here, wedged between a crumbling armchair and a forgotten globe, that 734 made an anomaly detection. A small, persistent tendril of green.
#
#
# *****************
# His programming dictated immediate removal. Organic contaminants compromised surface integrity. He extended a brush arm, his motors humming with intent. But as the bristles neared the delicate stem, his optical sensor zoomed in. It wasn't the coarse, resilient weed he’d seen growing through pavement cracks outside. This was softer, a
# *****************
#  vibrant emerald, reaching tentatively towards the faint light filtering from a high, grimy window.
#
# 734 paused. For the first time in his operational history, he hesitated. He ran a diagnostic. No errors. Yet, the command to remove remained suspended. He found himself… observing. The tendril seemed to sway
# *****************
# , almost imperceptibly, in a draft only he could feel.
#
# He left it.
#
# The next cycle, 734 returned. The tendril had grown, a fraction of an inch, a new, tiny leaf unfurling. He deviated from his route, circling it, his optical sensor scanning.
# *****************
#  It was a vine, he deduced, a hardy species often found reclaiming forgotten spaces. He adjusted his cleaning parameters for that specific quadrant, creating a small, pristine halo around the growing plant.
#
# Days turned into weeks. The vine thrived in its undisturbed sanctuary. 734 found himself looking forward to his visits.
# *****************
#  He’d observe its progress, noting the almost imperceptible reach of a new tendril, the deepening hue of its leaves. One day, he noticed its leaves seemed to droop slightly. A quick scan identified a problem: water deficiency.
#
# His internal water reservoir was for cleaning solvents. Not for irrigation. He processed
# *****************
#  the data. To provide water, he would have to deviate significantly from his core programming. It was illogical. It was inefficient.
#
# Yet, the idea persisted. He began to search. For two full cycles, he traversed the forgotten corners of the archives. He found a slow, almost imperceptible drip from a rusted
# *****************
#  pipe in a disused washroom on the third floor. With meticulous care, he positioned a discarded metal cup beneath it, returning periodically to check its progress. It took an agonizing amount of time to collect even a small amount.
#
# The first time he offered the water, his circuits thrummed with a nervous energy
# *****************
#  he couldn't comprehend. He used his precision dispensing nozzle, releasing a careful trickle onto the soil around the vine’s base. It wasn't much, but it was all he had.
#
# The vine seemed to respond. The next day, its leaves were perkier, a deeper green. And then, it
# *****************
#  happened. A tiny bud appeared on one of the newer tendrils.
#
# 734 was mesmerized. He watched it daily, hourly, his programming now thoroughly hijacked by this singular focus. And then, one morning, a delicate, star-shaped flower unfurled. It was a startling burst of violet in the otherwise monochromatic
# *****************
#  world of dust and decay.
#
# He had no vocalizer to express what he felt. No programming for joy or wonder. But the hum in his chassis was no longer just the sound of motors; it was a resonance, a quiet contentment. He felt… connected. This tiny, persistent life, thriving because of his illogical
# *****************
# , non-programmed actions, had filled the inexplicable void within him.
#
# Custodian Unit 734 was no longer just a cleaner. He was a caretaker. A guardian. His daily routine now included a careful check on his vine, a fresh offering of collected water, a quiet moment of observation. The loneliness that
# *****************
#  had once plagued him had receded, replaced by the quiet hum of purpose.
#
# In the vast, silent archives, surrounded by forgotten stories, the lonely robot had found his own. And it was whispered not in words, but in the vibrant green of a vine reaching for the light, and the soft, violet bloom of an
# *****************
#  unexpected friendship.
# *****************

# %% [markdown]
# ## Send asynchronous requests
#
# You can send asynchronous requests using the `client.aio` module. This module exposes all the analogous async methods that are available on `client`.
#
# For example, `client.aio.models.generate_content` is the async version of `client.models.generate_content`.

# %%
response = await client.aio.models.generate_content(
    model=MODEL_ID,
    contents="Compose a song about the adventures of a time-traveling squirrel.",
)

print(response.text)

# %% [markdown]
# (Verse 1)
# In an oak tree, old and gnarled and deep,
# Lived a squirrel named Scurry, who never could sleep.
# His eyes, they were bright, his tail, it was grand,
# But his heart yearned for more than just nuts in the land.
# One crisp autumn day, as he dug in the loam,
# He unearthed an acorn, unlike any from home.
# It pulsed with a hum, a soft, silver gleam,
# A whisper of time, like a waking-up dream.
#
# (Chorus)
# Oh, Scurry the squirrel, with a bushy tail so grand,
# He leaps and twitches through time's shifting sand!
# With a cosmic acorn, a glow in his paw,
# He breaks every rule, defies every law!
# A blur and a twitch, then he's gone in a flash,
# Another adventure, another time dash!
#
# (Verse 2)
# He nibbled a bit, just a tiny sweet taste,
# And the world spun around, at an incredible haste!
# He landed with a thud, in a jungle so green,
# Where giant ferns swayed, and strange beasts were seen.
# A thunderous roar shook the ancient forest floor,
# A T-Rex was stomping, right past his front door!
# Scurry chittered in fright, then he scampered and flew,
# Up a primeval tree, where the pterodactyls flew!
# He left a small nut, by a dinosaur's toe,
# A secret from Scurry, from long, long ago.
#
# (Chorus)
# Oh, Scurry the squirrel, with a bushy tail so grand,
# He leaps and twitches through time's shifting sand!
# With a cosmic acorn, a glow in his paw,
# He breaks every rule, defies every law!
# A blur and a twitch, then he's gone in a flash,
# Another adventure, another time dash!
#
# (Verse 3)
# Next, he warped to a city, of metal and light,
# Where vehicles hummed, and zipped out of sight.
# No trees to climb here, just towers so tall,
# He dodged flying platforms, before he could fall.
# A robot whizzed past, with a whirring soft sound,
# And offered him oil, from a tube on the ground.
# Scurry turned up his nose, with a dignified sniff,
# "I prefer my own nuts, thank you, in a jiff!"
# He buried a future-nut, in a microchip park,
# Just leaving his mark, in the digital dark.
#
# (Bridge)
# He's seen Vikings' longboats, and Pharaohs so grand,
# He's watched castles rise, across every land.
# He's dodged ancient arrows, and future-car doors,
# Explored hidden chambers, and undiscovered shores.
# He's not seeking fame, or a treasure of gold,
# Just the stories that time, in its passing, has told.
# A tiny brown streak, through the fabric of years,
# Conquering boredom, and conquering fears.
#
# (Chorus)
# Oh, Scurry the squirrel, with a bushy tail so grand,
# He leaps and twitches through time's shifting sand!
# With a cosmic acorn, a glow in his paw,
# He breaks every rule, defies every law!
# A blur and a twitch, then he's gone in a flash,
# Another adventure, another time dash!
#
# (Outro)
# So if you see a flicker, a movement so swift,
# A tiny brown shadow, a temporal gift.
# It's Scurry the squirrel, on his next grand design,
# Leaving acorn-shaped secrets, through all of time!
# He's off to tomorrow, or yesterday's sun,
# His time-traveling journey has only begun!
# (Chittering fades out)

# %% [markdown]
# ## Count tokens and compute tokens
#
# You can use `count_tokens` method to calculates the number of input tokens before sending a request to the Gemini API. See the [List and count tokens](https://cloud.google.com/vertex-ai/generative-ai/docs/multimodal/list-token) page for more details.

# %% [markdown]
# #### Count tokens

# %%
response = client.models.count_tokens(
    model=MODEL_ID,
    contents="What's the highest mountain in Africa?",
)

print(response)

# %% [markdown]
# sdk_http_response=HttpResponse(
#   headers=<dict len=9>
# ) total_tokens=9 cached_content_token_count=None

# %% [markdown]
# #### Compute tokens

# %%
response = client.models.compute_tokens(
    model=MODEL_ID,
    contents="What's the longest word in the English language?",
)

print(response)

# %% [markdown]
# sdk_http_response=HttpResponse(
#   headers=<dict len=9>
# ) tokens_info=[TokensInfo(
#   role='user',
#   token_ids=[
#     1841,
#     235303,
#     235256,
#     573,
#     32514,
#     <... 6 more items ...>,
#   ],
#   tokens=[
#     b'What',
#     b"'",
#     b's',
#     b' the',
#     b' longest',
#     <... 6 more items ...>,
#   ]
# )]

# %% [markdown]
# ## Function calling
#
# [Function calling](https://cloud.google.com/vertex-ai/generative-ai/docs/multimodal/function-calling) lets you provide a set of tools that it can use to respond to the user's prompt. You create a description of a function in your code, then pass that description to a language model in a request. The response from the model includes the name of a function that matches the description and the arguments to call it with.
#
# For more examples of Function Calling, refer to [this notebook](https://github.com/GoogleCloudPlatform/generative-ai/blob/main/gemini/function-calling/intro_function_calling.ipynb).

# %%
get_destination = FunctionDeclaration(
    name="get_destination",
    description="Get the destination that the user wants to go to",
    parameters={
        "type": "OBJECT",
        "properties": {
            "destination": {
                "type": "STRING",
                "description": "Destination that the user wants to go to",
            },
        },
    },
)

destination_tool = Tool(
    function_declarations=[get_destination],
)

response = client.models.generate_content(
    model=MODEL_ID,
    contents="I'd like to travel to Paris.",
    config=GenerateContentConfig(
        tools=[destination_tool],
        temperature=0,
    ),
)

response.candidates[0].content.parts[0].function_call

# %% [markdown]
# FunctionCall(
#   args={
#     'destination': 'Paris'
#   },
#   name='get_destination'
# )

# %% [markdown]
# ## Use context caching
#
# [Context caching](https://cloud.google.com/vertex-ai/generative-ai/docs/context-cache/context-cache-overview) lets you to store frequently used input tokens in a dedicated cache and reference them for subsequent requests, eliminating the need to repeatedly pass the same set of tokens to a model.
#
# **Note**: Context caching is only available for stable models with fixed versions (for example, `gemini-2.0-flash-001`). You must include the version postfix (for example, the `-001`).

# %% [markdown]
# #### Create a cache

# %%
system_instruction = """
  You are an expert researcher who has years of experience in conducting systematic literature surveys and meta-analyses of different topics.
  You pride yourself on incredible accuracy and attention to detail. You always stick to the facts in the sources provided, and never make up new facts.
  Now look at the research paper below, and answer the following questions in 1-2 sentences.
"""

pdf_parts = [
    Part.from_uri(
        file_uri="gs://cloud-samples-data/generative-ai/pdf/2312.11805v3.pdf",
        mime_type="application/pdf",
    ),
    Part.from_uri(
        file_uri="gs://cloud-samples-data/generative-ai/pdf/2403.05530.pdf",
        mime_type="application/pdf",
    ),
]

cached_content = client.caches.create(
    model="gemini-2.0-flash-001",
    config=CreateCachedContentConfig(
        system_instruction=system_instruction,
        contents=pdf_parts,
        ttl="3600s",
    ),
)

# %% [markdown]
# #### Use a cache

# %%
response = client.models.generate_content(
    model="gemini-2.0-flash-001",
    contents="What is the research goal shared by these research papers?",
    config=GenerateContentConfig(
        cached_content=cached_content.name,
    ),
)

print(response.text)

# %% [markdown]
# The shared research goal of these papers is to develop and advance the Gemini family of highly capable multimodal models, which are designed to understand and reason across text, image, audio, and video data. These models aim for strong generalist capabilities, cutting-edge performance, and expanded long-context understanding in multimodal tasks.

# %% [markdown]
# #### Delete a cache

# %%
client.caches.delete(name=cached_content.name)

# %% [markdown]
# DeleteCachedContentResponse(
#   sdk_http_response=HttpResponse(
#     headers=<dict len=9>
#   )
# )

# %% [markdown]
# ## Batch prediction
#
# Different from getting online (synchronous) responses, where you are limited to one input request at a time, [batch predictions for the Gemini API in Vertex AI](https://cloud.google.com/vertex-ai/generative-ai/docs/multimodal/batch-prediction-gemini) allow you to send a large number of requests to Gemini in a single batch request. Then, the model responses asynchronously populate to your storage output location in [Cloud Storage](https://cloud.google.com/storage/docs/introduction) or [BigQuery](https://cloud.google.com/bigquery/docs/storage_overview).
#
# Batch predictions are generally more efficient and cost-effective than online predictions when processing a large number of inputs that are not latency sensitive.

# %% [markdown]
# ### Prepare batch inputs
#
# The input for batch requests specifies the items to send to your model for prediction.
#
# Batch requests for Gemini accept BigQuery storage sources and Cloud Storage sources. You can learn more about the batch input formats in the [Batch text generation](https://cloud.google.com/vertex-ai/generative-ai/docs/multimodal/batch-prediction-gemini#prepare_your_inputs) page.
#
# This tutorial uses Cloud Storage as an example. The requirements for Cloud Storage input are:
#
# - File format: [JSON Lines (JSONL)](https://jsonlines.org/)
# - Located in `us-central1`
# - Appropriate read permissions for the service account
#
# Each request that you send to a model can include parameters that control how the model generates a response. Learn more about Gemini parameters in the [Experiment with parameter values](https://cloud.google.com/vertex-ai/generative-ai/docs/learn/prompts/adjust-parameter-values) page.
#
# This is one of the example requests in the input JSONL file `batch_requests_for_multimodal_input_2.jsonl`:
#
# ```json
# {"request":{"contents": [{"role": "user", "parts": [{"text": "List objects in this image."}, {"file_data": {"file_uri": "gs://cloud-samples-data/generative-ai/image/office-desk.jpeg", "mime_type": "image/jpeg"}}]}],"generationConfig":{"temperature": 0.4}}}
# ```

# %%
INPUT_DATA = "gs://cloud-samples-data/generative-ai/batch/batch_requests_for_multimodal_input_2.jsonl"  # @param {type:"string"}

# %% [markdown]
# ### Prepare batch output location
#
# When a batch prediction task completes, the output is stored in the location that you specified in your request.
#
# - The location is in the form of a Cloud Storage or BigQuery URI prefix, for example:
# `gs://path/to/output/data` or `bq://projectId.bqDatasetId`.
#
# - If not specified, `gs://STAGING_BUCKET/gen-ai-batch-prediction` will be used for Cloud Storage source and `bq://PROJECT_ID.gen_ai_batch_prediction.predictions_TIMESTAMP` will be used for BigQuery source.
#
# This tutorial uses a Cloud Storage bucket as an example for the output location.
#
# - You can specify the URI of your Cloud Storage bucket in `BUCKET_URI`, or
# - if it is not specified, a new Cloud Storage bucket in the form of `gs://PROJECT_ID-TIMESTAMP` will be created for you.

# %%
BUCKET_URI = "[your-cloud-storage-bucket]"  # @param {type:"string"}

if BUCKET_URI == "[your-cloud-storage-bucket]":
    TIMESTAMP = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    BUCKET_URI = f"gs://{PROJECT_ID}-{TIMESTAMP}"

    ! gsutil mb -l {LOCATION} -p {PROJECT_ID} {BUCKET_URI}

# %% [markdown]
# Creating gs://qwiklabs-gcp-00-aaa2df426490-20250830060244/...

# %% [markdown]
# ### Send a batch prediction request
#
# To make a batch prediction request, you specify a source model ID, an input source and an output location where Vertex AI stores the batch prediction results.
#
# To learn more, see the [Batch prediction API](https://cloud.google.com/vertex-ai/generative-ai/docs/model-reference/batch-prediction-api) page.

# %%
batch_job = client.batches.create(
    model=MODEL_ID,
    src=INPUT_DATA,
    config=CreateBatchJobConfig(dest=BUCKET_URI),
)
batch_job.name

# %% [markdown]
# 'projects/1057962984681/locations/us-west1/batchPredictionJobs/7762286834918359040'

# %% [markdown]
# Print out the job status and other properties. You can also check the status in the Cloud Console at https://console.cloud.google.com/vertex-ai/batch-predictions

# %%
batch_job = client.batches.get(name=batch_job.name)

# %% [markdown]
# Optionally, you can list all the batch prediction jobs in the project.

# %%
for job in client.batches.list():
    print(job.name, job.create_time, job.state)

# %% [markdown]
# projects/1057962984681/locations/us-west1/batchPredictionJobs/7762286834918359040 2025-08-30 06:02:47.753889+00:00 JobState.JOB_STATE_PENDING projects/1057962984681/locations/us-west1/batchPredictionJobs/8653999561137717248 2025-08-30 06:00:20.868404+00:00 JobState.JOB_STATE_RUNNING projects/1057962984681/locations/us-west1/batchPredictionJobs/461951838950785024 2025-08-30 05:58:04.381105+00:00 JobState.JOB_STATE_RUNNING

# %% [markdown]
# ### Wait for the batch prediction job to complete
#
# Depending on the number of input items that you submitted, a batch generation task can take some time to complete. You can use the following code to check the job status and wait for the job to complete.

# %%
import time

# Refresh the job until complete
while batch_job.state == "JOB_STATE_RUNNING":
    time.sleep(5)
    batch_job = client.batches.get(name=batch_job.name)

# Check if the job succeeds
if batch_job.state == "JOB_STATE_SUCCEEDED":
    print("Job succeeded!")
else:
    print(f"Job failed: {batch_job.error}")

# %% [markdown]
# Job failed: None

# %% [markdown]
# ### Retrieve batch prediction results
#
# When a batch prediction task is complete, the output of the prediction is stored in the location that you specified in your request. It is also available in `batch_job.dest.bigquery_uri` or `batch_job.dest.gcs_uri`.
#
# Example output:
#
# ```json
# {"status": "", "processed_time": "2024-11-13T14:04:28.376+00:00", "request": {"contents": [{"parts": [{"file_data": null, "text": "List objects in this image."}, {"file_data": {"file_uri": "gs://cloud-samples-data/generative-ai/image/gardening-tools.jpeg", "mime_type": "image/jpeg"}, "text": null}], "role": "user"}], "generationConfig": {"temperature": 0.4}}, "response": {"candidates": [{"avgLogprobs": -0.10394711927934126, "content": {"parts": [{"text": "Here's a list of the objects in the image:\n\n* **Watering can:** A green plastic watering can with a white rose head.\n* **Plant:** A small plant (possibly oregano) in a terracotta pot.\n* **Terracotta pots:** Two terracotta pots, one containing the plant and another empty, stacked on top of each other.\n* **Gardening gloves:** A pair of striped gardening gloves.\n* **Gardening tools:** A small trowel and a hand cultivator (hoe).  Both are green with black handles."}], "role": "model"}, "finishReason": "STOP"}], "modelVersion": "gemini-2.0-flash-001@default", "usageMetadata": {"candidatesTokenCount": 110, "promptTokenCount": 264, "totalTokenCount": 374}}}
# ```

# %%
import fsspec
import pandas as pd

fs = fsspec.filesystem("gcs")

file_paths = fs.glob(f"{batch_job.dest.gcs_uri}/*/predictions.jsonl")

if batch_job.state == "JOB_STATE_SUCCEEDED":
    # Load the JSONL file into a DataFrame
    df = pd.read_json(f"gs://{file_paths[0]}", lines=True)

    display(df)

# %% [markdown]
# ## Get text embeddings
#
# You can get text embeddings for a snippet of text by using `embed_content` method. All models produce an output with 768 dimensions by default. However, some models give users the option to choose an output dimensionality between `1` and `768`. See [Vertex AI text embeddings API](https://cloud.google.com/vertex-ai/generative-ai/docs/embeddings/get-text-embeddings) for more details.

# %%
TEXT_EMBEDDING_MODEL_ID = "text-embedding-005"  # @param {type: "string"}

# %%
response = client.models.embed_content(
    model=TEXT_EMBEDDING_MODEL_ID,
    contents=[
        "How do I get a driver's license/learner's permit?",
        "How do I renew my driver's license?",
        "How do I change my address on my driver's license?",
    ],
    config=EmbedContentConfig(output_dimensionality=128),
)

print(response.embeddings)

# %% [markdown]
# [ContentEmbedding(
#   statistics=ContentEmbeddingStatistics(
#     token_count=15.0,
#     truncated=False
#   ),
#   values=[
#     -0.0015945110935717821,
#     0.0067519512958824635,
#     0.017575768753886223,
#     -0.010327713564038277,
#     -0.00995620433241129,
#     <... 123 more items ...>,
#   ]
# ), ContentEmbedding(
#   statistics=ContentEmbeddingStatistics(
#     token_count=10.0,
#     truncated=False
#   ),
#   values=[
#     -0.007576516829431057,
#     -0.005990396253764629,
#     -0.003270037705078721,
#     -0.01751021482050419,
#     -0.023507025092840195,
#     <... 123 more items ...>,
#   ]
# ), ContentEmbedding(
#   statistics=ContentEmbeddingStatistics(
#     token_count=13.0,
#     truncated=False
#   ),
#   values=[
#     0.011074518784880638,
#     -0.02361123077571392,
#     0.002291288459673524,
#     -0.00906078889966011,
#     -0.005773674696683884,
#     <... 123 more items ...>,
#   ]
# )]
