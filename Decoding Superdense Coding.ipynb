# %%
# !pip install qiskit
# !pip install qiskit-aer

# %%
# %matplotlib inline

from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# Superdense Coding - sending '11'
qc = QuantumCircuit(2, 2)

# Step 1: Create Bell state
qc.h(0)
qc.cx(0, 1)

# Step 2: Alice encodes message '11' using Z + X
qc.z(0)
qc.x(0)

# Step 3: Bob decodes
qc.cx(0, 1)
qc.h(0)

# Step 4: Measure
qc.measure(0, 0)
qc.measure(1, 1)

# Simulate
backend = Aer.get_backend('qasm_simulator')
job = backend.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()

# Show histogram
plot_histogram(counts)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 5, 6])
plt.title("Test Plot")
plt.show()

# %%
# !pip install qiskit qiskit-aer --quiet

# %%
# MUST be at top
# %matplotlib inline

# Install Qiskit (do this once if not already)
# !pip install qiskit --quiet

# Imports
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# Build the quantum circuit for superdense coding
qc = QuantumCircuit(2, 2)

# Step 1: Create Bell state (shared entangled pair)
qc.h(0)
qc.cx(0, 1)

# Step 2: Encode message '11' using Z and X gates on qubit 0
qc.z(0)
qc.x(0)

# Step 3: Bob decodes the qubit
qc.cx(0, 1)
qc.h(0)

# Step 4: Measure both qubits
qc.measure(0, 0)
qc.measure(1, 1)

# Simulate on local Aer simulator
simulator = Aer.get_backend('qasm_simulator')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()

# Show result as histogram
plot_histogram(counts)
plt.show()
